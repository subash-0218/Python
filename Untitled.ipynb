# %%
a=10

# %%
a.bit_length()
# Out:
# 4

# %%
a = 'nikhil'
a
# Out:
# 'nikhil'

# %%
# 654321    - right to left
# nikhil
# 012345    - left to right
     

#a[0:n] # a[ 0 to n-1]

print(a[0:3])
print(a[1:4])
print(a[:])
print(a[:5]) # 0 to 4
print(a[:5:2])
print(a[-1::-1])
print(a[-1:-6:-1])
print(a[4:-6:-1])
# Out:
# nik
# ikh
# nikhil
# nikhi
# nki
# lihkin
# lihki
# ihki

# %%
a="venkat"
print(a[5:0:-1])
# Out:
# takne

# %%
a="jayanthini"
print(a[0:5:1])
# Out:
# jayan

# %%
"""hi.bye.\nsee""".splitlines()
# Out:
# ['hi.bye.', 'see']

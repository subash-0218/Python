# %% [markdown]
# ### DataFrame.add_suffix(suffix, axis=None)

# %% [markdown]
# 1. Suffix labels with string suffix.
# 2. For Series, the row labels are suffixed.
# 3. For DataFrame, the column labels are suffixed.

# %% [markdown]
# ### Parameters:
# suffix:str,The string to add after each label.
#
# axis:{0 or ‘index’, 1 or ‘columns’, None}, default None
# Axis to add suffix on

# %% [markdown]
# ### Returns:
# New Series or DataFrame with updated labels.

# %%
import pandas as pd
s = pd.Series([1, 2, 3, 4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s.add_suffix('_item')
# Out:
# 0_item    1
# 1_item    2
# 2_item    3
# 3_item    4
# dtype: int64

# %%
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [3, 4, 5, 6]})
df
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  3  5
# 3  4  6

# %%
df.add_suffix('_col',axis=0)
df.add_suffix('_col',axis=1)
# Out:
#    A_col  B_col
# 0      1      3
# 1      2      4
# 2      3      5
# 3      4      6
